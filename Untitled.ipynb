# %%
import urllib.request
entries = urllib.request.urlopen('https://product-api.paulaschoice.tech/all').read()

# %% [markdown]
# import json
# s=json.dumps(entries)
# print(s)

# %%
entries
# Out:
# b'[{"Barcode":"655439010009","Name":"Moisture Boost One Step Face Cleanser","SKU":"1000","concerns_addressed":[],"min_req":["Normal","Dry to Very Dry"],"rating":"93","reviews":{"1":"5","2":"9","3":"14","4":"11","5":"164"},"shopifyID":"8561835335","type":"Cleanser","handle":"moisture-boost-one-step-face-cleanser","url":"https://paulaschoice.sg/products/moisture-boost-one-step-face-cleanser","image_url":"https://cdn.shopify.com/s/files/1/1440/2440/products/ihwx.c47a6d84-c49d-4ac9-8109-f776bc09251e.1200.800.png?v=1471414608","usa_url":"https://paulaschoice.com/100.html","key_benefits":["Skin-softening formula effectively removes makeup","Leaves skin beautifully soft yet thoroughly cleansed","Hydrating lotion formula","Use as the first step in your AM/PM skincare routine"],"first_description":"This lotion cleanser quickly and gently lifts away impurities and makeup, leaving skin feeling refreshed but not tight or dry.","ingredients":"Water, Sodium Laureth Sulfate (gentle cleansing agent)
# ...

# %%
import requests
r = requests.get('https://product-api.paulaschoice.tech/all')
r.json()[0:3]
# Out:
# [{'Barcode': '655439010009',
#   'Name': 'Moisture Boost One Step Face Cleanser',
#   'SKU': '1000',
#   'concerns_addressed': [],
#   'first_description': 'This lotion cleanser quickly and gently lifts away impurities and makeup, leaving skin feeling refreshed but not tight or dry.',
#   'handle': 'moisture-boost-one-step-face-cleanser',
#   'image_url': 'https://cdn.shopify.com/s/files/1/1440/2440/products/ihwx.c47a6d84-c49d-4ac9-8109-f776bc09251e.1200.800.png?v=1471414608',
# ...

# %%
x = 1+3 
print(x)
# Out:
# 4
