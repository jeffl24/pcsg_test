# %%
import numpy as np
import pandas as pd

# %%
sales_data = pd.read_csv("pcsg_cust_orders_export.csv", header = 0, low_memory=False, index_col="Name")
sales_data.head()
# Out:
#                                   Email Financial Status  \
# Name
# 191569910468    c_chien_may@hotmail.com             paid
# 191569914-1221    trymeepoh@hotmail.com             paid
# 191569914-1221    trymeepoh@hotmail.com              NaN
# 191569914-1221    trymeepoh@hotmail.com              NaN
# 191569914-1220   lxy_cheryl@hotmail.com             paid
#
#                                   Paid at Fulfillment Status  \
# Name
# 191569910468    2017-09-28 13:33:13 +0800        unfulfilled
# 191569914-1221  2017-09-28 13:32:17 +0800          fulfilled
# 191569914-1221                        NaN                NaN
# 191569914-1221                        NaN                NaN
# 191569914-1220  2017-09-28 12:44:29 +0800          fulfilled
#
#                              Fulfilled at Accepts Marketing Currency  \
# Name
# 191569910468                          NaN                no      SGD
# 191569914-1221  2017-09-28 13:32:17 +0800               yes      SGD
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20853 entries, 191569910468 to #1002
# Data columns (total 70 columns):
# Email                          17134 non-null object
# Financial Status               9464 non-null object
# Paid at                        8967 non-null object
# Fulfillment Status             9464 non-null object
# Fulfilled at                   9426 non-null object
# Accepts Marketing              9464 non-null object
# Currency                       9464 non-null object
# Subtotal                       9464 non-null float64
# Shipping                       9464 non-null float64
# Taxes                          9464 non-null float64
# Total                          9464 non-null float64
# Discount Code                  1891 non-null object
# Discount Amount                9464 non-null float64
# Shipping Method                4340 non-null object
# Created at                     20853 non-null object
# Lineitem quantity              20853 non-null int64
# ...

# %%
sales_data_clean = sales_data.drop(sales_data.columns.to_series()[-11:-1], axis=1)
sales_data_clean
# Out:
#                                        Email Financial Status  \
# Name
# 191569910468         c_chien_may@hotmail.com             paid
# 191569914-1221         trymeepoh@hotmail.com             paid
# 191569914-1221         trymeepoh@hotmail.com              NaN
# 191569914-1221         trymeepoh@hotmail.com              NaN
# 191569914-1220        lxy_cheryl@hotmail.com             paid
# 191569910465          lee_aileen@hotmail.com             paid
# 191569910465          lee_aileen@hotmail.com              NaN
# 191569910464        demona.pastime@gmail.com             paid
# 191569910464        demona.pastime@gmail.com              NaN
# 191569910463    johnsonbabyshampoo@gmail.com             paid
# 191569910463    johnsonbabyshampoo@gmail.com              NaN
# 191569910462           sophidarl@yahoo.co.in             paid
# 191569910461            adam.aysha@gmail.com             paid
# 191569910461            adam.aysha@gmail.com              NaN
# ...

# %%
sales_data['Paid at'] = pd.to_datetime(sales_data['Paid at'])
sales_data['Fulfilled at'] = pd.to_datetime(sales_data['Fulfilled at'])
sales_data['Created at'] = pd.to_datetime(sales_data['Created at'])
# sales_data['Combined Time Serial'] = pd.to_datetime(sales_data['Combined Time Serial'])
sales_data['Fulfilled at'][:15]
# Out:
# Name
# 191569910468                     NaT
# 191569914-1221   2017-09-28 05:32:17
# 191569914-1221                   NaT
# 191569914-1221                   NaT
# 191569914-1220   2017-09-28 04:44:29
# 191569910465                     NaT
# 191569910465                     NaT
# 191569910464                     NaT
# 191569910464                     NaT
# 191569910463                     NaT
# 191569910463                     NaT
# 191569910462                     NaT
# 191569910461                     NaT
# 191569910461                     NaT
# 191569910461                     NaT
# Name: Fulfilled at, dtype: datetime64[ns]

# %%
# df['CohortGroup'] = df.groupby(level=0)['OrderDate'].min().apply(lambda x: x.strftime('%Y-%m'))
# sales_pivot = pd.DataFrame(sales_data(['Email', 'Location', 'Name', 'Created at'])['Total'].sum())
sales_data_group = pd.DataFrame(sales_data.groupby(['Email', 'Created at', 'Lineitem sku'])['Lineitem price'].sum())
sales_data_group
# Out:
#                                                               Lineitem price
# Email                       Created at          Lineitem sku
# 001coolgal@gmail.com        2016-12-24 11:28:39 1101                    50.0
#                                                 6100                    29.0
#                                                 7740                    45.0
#                                                 7780                    33.0
#                                                 7820                    41.0
#                                                 7860                    65.0
#                             2017-02-13 12:55:58 7710                    52.0
#                                                 7910                    58.0
#                             2017-02-28 12:30:48 7960                    68.0
# 007lavender@gmail.com       2017-01-02 07:25:17 1350                    34.0
# ...

# %%
sales_data_group['TranCount'] = sales_data_group.groupby(level=1).rank(axis = 0, method = 'dense', ascending = True)
sales_data_group

# df.groupby(level=1).rank(ascending=False)
# sales_data_reset['TranCount'] = sales_data_reset.groupby(level=1)['Created at'].rank(method = 'dense', ascending = True)
# Out:
#                                                               Lineitem price  \
# Email                       Created at          Lineitem sku
# 001coolgal@gmail.com        2016-12-24 11:28:39 1101                    50.0
#                                                 6100                    29.0
#                                                 7740                    45.0
#                                                 7780                    33.0
#                                                 7820                    41.0
#                                                 7860                    65.0
#                             2017-02-13 12:55:58 7710                    52.0
#                                                 7910                    58.0
#                             2017-02-28 12:30:48 7960                    68.0
# 007lavender@gmail.com       2017-01-02 07:25:17 1350                    34.0
# ...

# %%
sales_data_group_2 = pd.DataFrame(sales_data.groupby(['Email', 'Created at'])['Lineitem price'].sum())
sales_data_group_2.reset_index(level = 'Created at', inplace=True)
sales_data_group_2['TranCount'] = sales_data_group_2.groupby(level=0).rank(axis = 1, method = 'dense', ascending = False)
sales_data_group_2
# Out:
#                                      Created at  Lineitem price  TranCount
# Email
# 001coolgal@gmail.com        2016-12-24 11:28:39           263.0        1.0
# 001coolgal@gmail.com        2017-02-13 12:55:58           110.0        1.0
# 001coolgal@gmail.com        2017-02-28 12:30:48            68.0        1.0
# 007lavender@gmail.com       2017-01-02 07:25:17           170.0        1.0
# 0306isabel@gmail.com        2017-06-28 11:15:48           519.0        1.0
# 0306isabel@gmail.com        2017-07-31 11:14:13           257.0        1.0
# 1070504395@qq.com           2017-09-06 06:10:33            44.0        1.0
# 1293590203@qq.com           2017-06-16 05:06:50           128.5        1.0
# 1404225C@gmail.com          2017-06-27 09:11:22            43.0        1.0
# 15049659myrp@gmail.com      2017-08-14 11:43:59            49.0        1.0
# 15049659myrp@gmail.com      2017-08-14 11:47:16            49.0        1.0
# ...

# %%
sales_data_group_2.reset_index(inplace=True)
sales_data_group_2

# %%
TranCountSource =
